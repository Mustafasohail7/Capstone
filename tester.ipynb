# %%
from API.main import main

start_date = '2024-01-01'
end_date = '2024-03-01'
file_path = 'API/testing_coords.txt'

main(start_date, end_date, file_path)
# Out:
# coordinate: 1 out of 3
# 5 scenes found.
# date chosen 2024-02-23 00:00:00
# --------------------------
# Download options found
# --------------------------
# Products available to download:  8
# --------------------------
# All downloads available
# --------------------------
# Downloading L2SR_LC09_L2SP_152044_20240223_20240225_02_T1_SR_B3.TIF
# testing
# requesting session
# https://dds.cr.usgs.gov/download/eyJpZCI6NjAwMjI5MjA0LCJjb250YWN0SWQiOjI2ODg3OTMzfQ==
# got response
# downloading from here
# File downloaded successfully.
# --------------------------
# Downloading L2SR_LC09_L2SP_152044_20240223_20240225_02_T1_SR_B5.TIF
# testing
# requesting session
# https://dds.cr.usgs.gov/download/eyJpZCI6NjAwMjI5MjA1LCJjb250YWN0SWQiOjI2ODg3OTMzfQ==
# got response
# downloading from here
# File downloaded successfully.
# --------------------------
# Downloading L2SR_LC09_L2SP_152044_20240223_20240225_02_T1_SR_B6.TIF
# testing
# requesting session
# https://dds.cr.usgs.gov/download/eyJpZCI6NjAwMjI5MjA2LCJjb250YWN0SWQiOjI2ODg3OTMzfQ==
# got response
# downloading from here
# File downloaded successfully.
# --------------------------
# Downloading L2SR_LC09_L2SP_152044_20240223_20240225_02_T1_SR_B7.TIF
# testing
# requesting session
# https://dds.cr.usgs.gov/download/eyJpZCI6NjAwMjI5MjA3LCJjb250YWN0SWQiOjI2ODg3OTMzfQ==
# got response
# downloading from here
# File downloaded successfully.
# --------------------------
# coordinate: 2 out of 3
# 4 scenes found.
# date chosen 2024-02-23 00:00:00
# --------------------------
# Download options found
# --------------------------
# Products available to download:  8
# --------------------------
# No download options found
# coordinate: 3 out of 3
# 3 scenes found.
# date chosen 2024-02-23 00:00:00
# --------------------------
# Download options found
# --------------------------
# Products available to download:  8
# --------------------------
# All downloads available
# --------------------------
# Downloading L2SR_LC09_L2SP_152042_20240223_20240225_02_T1_SR_B3.TIF
# testing
# requesting session
# https://dds.cr.usgs.gov/download/eyJpZCI6NjAwMjQyMTI1LCJjb250YWN0SWQiOjI2ODg3OTMzfQ==
# got response
# downloading from here
# File downloaded successfully.
# --------------------------
# Downloading L2SR_LC09_L2SP_152042_20240223_20240225_02_T1_SR_B5.TIF
# testing
# requesting session
# https://dds.cr.usgs.gov/download/eyJpZCI6NjAwMjQyMTI3LCJjb250YWN0SWQiOjI2ODg3OTMzfQ==
# got response
# downloading from here
# File downloaded successfully.
# --------------------------
# Downloading L2SR_LC09_L2SP_152042_20240223_20240225_02_T1_SR_B6.TIF
# testing
# requesting session
# https://dds.cr.usgs.gov/download/eyJpZCI6NjAwMjQyMTI4LCJjb250YWN0SWQiOjI2ODg3OTMzfQ==
# got response
# downloading from here
# File downloaded successfully.
# --------------------------
# Downloading L2SR_LC09_L2SP_152042_20240223_20240225_02_T1_SR_B7.TIF
# testing
# requesting session
# https://dds.cr.usgs.gov/download/eyJpZCI6NjAwMjQyMTI5LCJjb250YWN0SWQiOjI2ODg3OTMzfQ==
# got response
# downloading from here
# File downloaded successfully.
# --------------------------
